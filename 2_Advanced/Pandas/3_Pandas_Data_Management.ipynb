# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# 780907              Data Engineer with Fivetran,Qlik Must
#
#                      job_location                 job_via job_schedule_type  \
# 502901                St Paul, MN               via BeBee         Full-time
# 406337                 London, UK            via LinkedIn         Full-time
# 659951    Newcastle upon Tyne, UK              via Indeed         Full-time
# 541593                      Malta         via Trabajo.org         Full-time
# 425158     Amsterdam, Netherlands          via NBC4i Jobs         Full-time
# 183426                  Singapore  via Singapore | JobsDB         Full-time
# 287790                  Tampa, FL            via LinkedIn         Full-time
# 541983              Chantilly, VA      via Clearance Jobs         Full-time
# 416896                     France            via LinkedIn         Full-time
# 780907  Mexico City, CDMX, Mexico        via BeBee México         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
# 183426               False               Singapore 2023-11-09 16:07:57
# 287790               False  Florida, United States 2023-07-14 17:02:23
# 541983               False                 Georgia 2023-06-15 19:44:34
# 416896               False                  France 2023-09-22 16:47:24
# 780907               False                  Mexico 2023-01-16 06:19:09
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
# 183426                  False                 False       Singapore
# 287790                   True                 False   United States
# 541983                  False                 False   United States
# 416896                  False                 False          France
# 780907                  False                 False          Mexico
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901        None              NaN              NaN           ManpowerGroup
# 406337        None              NaN              NaN                 Harnham
# 659951        None              NaN              NaN             Morgan King
# 541593        None              NaN              NaN                 Konnekt
# 425158        None              NaN              NaN  Independent Recruiters
# 183426        None              NaN              NaN    FLEXOSENSE PTE. LTD.
# 287790        None              NaN              NaN      Iris Software Inc.
# 541983        None              NaN              NaN                    SAIC
# 416896        None              NaN              NaN             KPMG France
# 780907        None              NaN              NaN        CORUS Consulting
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
# 541593                                           ['jira']
# 425158                                         ['python']
# 183426  ['r', 'python', 'java', 'sql', 'sql server', '...
# 287790                         ['sql', 'hadoop', 'excel']
# 541983  ['sql', 'r', 'matlab', 'python', 'oracle', 'aw...
# 416896                                               None
# 780907  ['oracle', 'snowflake', 'aws', 'azure', 'alter...
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}
# 183426  {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 287790  {'analyst_tools': ['excel'], 'libraries': ['ha...
# 541983  {'analyst_tools': ['power bi', 'tableau', 'qli...
# 416896                                               None
# 780907  {'analyst_tools': ['alteryx'], 'cloud': ['orac...

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

df_altered = df_original

# %%
median_salary = df_altered.salary_year_avg.median()

median_salary
# Out:
# 115000.0

# %%
df_altered.salary_year_avg = df_altered.salary_year_avg.fillna(median_salary)

df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
id(df_original)
# Out:
# 2285506104208

# %%
id(df_altered)
# Out:
# 2285347406224

# %%
df_altered = df_original.copy()

# %% [markdown]
# Problems

# %%
df1 = df.copy()

df1 = df1.dropna(subset=['salary_year_avg'])
df1
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# 28      San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                                Arlington, VA     via LinkedIn
# 92                                     Anywhere     via LinkedIn
# 100                           Mountain View, CA     via LinkedIn
# 109                                    Anywhere       via Get.It
# ...                                         ...              ...
# 785624                          Mt Prospect, IL  via Ai-Jobs.net
# 785641                             New York, NY         via Dice
# 785648                        Pleasant Hill, CA  via Ai-Jobs.net
# 785682                      Reutlingen, Germany  via Ai-Jobs.net
# 785692                               Dayton, OH  via Ai-Jobs.net
#
#        job_schedule_type  job_work_from_home            search_location  \
# 28             Full-time               False                 Costa Rica
# 77             Full-time               False                      Sudan
# 92             Full-time                True    Illinois, United States
# 100            Full-time               False  California, United States
# 109            Full-time                True    Illinois, United States
# ...                  ...                 ...                        ...
# 785624         Full-time               False    Illinois, United States
# 785641         Full-time               False                    Georgia
# 785648         Full-time               False  California, United States
# 785682         Full-time               False                    Germany
# 785692         Full-time               False    Illinois, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 28     2023-08-01 13:37:57                  False                 False
# 77     2023-06-26 14:22:54                  False                 False
# 92     2023-02-21 13:29:59                  False                  True
# 100    2023-07-31 13:01:18                  False                  True
# 109    2023-10-12 13:02:19                  False                  True
# ...                    ...                    ...                   ...
# 785624 2023-08-31 06:02:16                  False                  True
# 785641 2023-01-04 16:36:07                   True                 False
# 785648 2023-04-12 06:02:51                  False                  True
# 785682 2023-03-04 06:16:08                  False                 False
# 785692 2023-04-21 06:02:31                  False                  True
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 28         Costa Rica        year         109500.0              NaN
# 77              Sudan        year         140000.0              NaN
# 92      United States        year         120000.0              NaN
# 100     United States        year         228222.0              NaN
# 109     United States        year          89000.0              NaN
# ...               ...         ...              ...              ...
# 785624  United States        year         139216.0              NaN
# 785641  United States        year         150000.0              NaN
# 785648  United States        year         221875.0              NaN
# 785682        Germany        year         157500.0              NaN
# 785692  United States        year         157500.0              NaN
#
#                            company_name  \
# 28                             Netskope
# 77                           Intelletec
# 92                         Apex Systems
# 100                              TikTok
# 109     Get It Recruit - Transportation
# ...                                 ...
# 785624                      Bosch Group
# 785641            Engage Partners, Inc.
# 785648                           84.51°
# 785682                      Bosch Group
# 785692                           Tenet3
#
#                                                job_skills  \
# 28                                      ['gdpr', 'excel']
# 77      ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 92                                      ['sql', 'python']
# 100                     ['sql', 'r', 'python', 'express']
# 109                 ['python', 'r', 'alteryx', 'tableau']
# ...                                                   ...
# 785624  ['go', 'python', 'r', 'sql', 'oracle', 'window...
# 785641                                               None
# 785648          ['python', 'azure', 'snowflake', 'spark']
# 785682  ['python', 'hadoop', 'spark', 'airflow', 'kube...
# 785692                          ['python', 'matlab', 'r']
#
#                                           job_type_skills
# 28      {'analyst_tools': ['excel'], 'libraries': ['gd...
# 77      {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 92                     {'programming': ['sql', 'python']}
# 100     {'programming': ['sql', 'r', 'python'], 'webfr...
# 109     {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# ...                                                   ...
# 785624  {'analyst_tools': ['alteryx', 'power bi', 'tab...
# 785641                                               None
# 785648  {'cloud': ['azure', 'snowflake'], 'libraries':...
# 785682  {'libraries': ['hadoop', 'spark', 'airflow'], ...
# 785692         {'programming': ['python', 'matlab', 'r']}
#
# [22003 rows x 17 columns]

# %%
df.sample(10)
# Out:
#               job_title_short                                job_title  \
# 708131           Data Analyst                     Medical Data Analyst
# 558633         Data Scientist                           Data Scientist
# 58082          Data Scientist            Data scientist h/f - bordeaux
# 589837      Software Engineer                      Power Apps Engineer
# 228591           Data Analyst                 Consultor Data Analytics
# 578177         Data Scientist               Entry Level Data Scientist
# 782076           Data Analyst                             Data Analyst
# 361123           Data Analyst                             Data Analyst
# 190795       Business Analyst                      IT Business Analyst
# 297388  Senior Data Scientist  Senior Data Scientist, Python, big data
#
#             job_location                                        job_via  \
# 708131  Jacksonville, FL                                      via BeBee
# 558633   Berlin, Germany                          via BeBee Deutschland
# 58082   Bordeaux, France                                   via LinkedIn
# 589837    Puebla, Mexico                                      via BeBee
# 228591   Santiago, Chile  via Trabajo.org - Vacantes De Empleo, Trabajo
# 578177      Delaware, OH                                      via BeBee
# 782076       Netherlands                            via BeBee Nederland
# 361123      New York, NY                                     via Indeed
# 190795   Porto, Portugal                             via BeBee Portugal
# 297388       Houston, TX                                   via LinkedIn
#
#        job_schedule_type  job_work_from_home          search_location  \
# 708131         Full-time               False   Florida, United States
# 558633         Full-time               False                  Germany
# 58082          Full-time               False                   France
# 589837         Full-time               False                   Mexico
# 228591         Full-time               False                    Chile
# 578177         Full-time               False  Illinois, United States
# 782076         Full-time               False              Netherlands
# 361123         Full-time               False  New York, United States
# 190795         Full-time               False                 Portugal
# 297388        Contractor               False                    Sudan
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 708131 2023-11-26 02:02:17                  False                  True
# 558633 2023-05-25 04:16:42                  False                 False
# 58082  2023-02-13 06:31:13                  False                 False
# 589837 2023-10-25 09:12:31                   True                 False
# 228591 2023-07-29 07:13:08                   True                 False
# 578177 2023-04-29 09:05:13                  False                 False
# 782076 2023-01-19 06:26:30                  False                 False
# 361123 2023-06-21 23:00:04                  False                  True
# 190795 2023-09-24 15:08:26                  False                 False
# 297388 2023-11-30 18:00:17                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 708131  United States        None              NaN              NaN
# 558633        Germany        None              NaN              NaN
# 58082          France        None              NaN              NaN
# 589837         Mexico        None              NaN              NaN
# 228591          Chile        None              NaN              NaN
# 578177  United States        None              NaN              NaN
# 782076    Netherlands        None              NaN              NaN
# 361123  United States        None              NaN              NaN
# 190795       Portugal        None              NaN              NaN
# 297388          Sudan        None              NaN              NaN
#
#                         company_name  \
# 708131         College of Charleston
# 558633                  Marley Spoon
# 58082              Société Free-Work
# 589837                 ExactlyIT Inc
# 228591  Falabella Equipo Corporativo
# 578177                 SynergisticIT
# 782076            Visser & Van Baars
# 361123              Integra Partners
# 190795                      SysMatch
# 297388                Computer Staff
#
#                                                job_skills  \
# 708131                                               None
# 558633  ['python', 'snowflake', 'numpy', 'scikit-learn...
# 58082   ['python', 'sql', 'azure', 'aws', 'tensorflow'...
# 589837  ['python', 'powershell', 'bash', 'azure', 'gcp...
# 228591                                     ['javascript']
# 578177  ['python', 'numpy', 'seaborn', 'plotly', 'tens...
# 782076  ['sql', 'python', 'postgresql', 'aws', 'redshi...
# 361123              ['sql', 'sas', 'sas', 'r', 'tableau']
# 190795                                   ['cobol', 'db2']
# 297388  ['python', 'sql', 'aws', 'pandas', 'pytorch', ...
#
#                                           job_type_skills
# 708131                                               None
# 558633  {'analyst_tools': ['looker'], 'cloud': ['snowf...
# 58082   {'analyst_tools': ['tableau', 'power bi'], 'cl...
# 589837  {'analyst_tools': ['power bi'], 'cloud': ['azu...
# 228591                    {'programming': ['javascript']}
# 578177  {'analyst_tools': ['tableau', 'excel'], 'libra...
# 782076  {'analyst_tools': ['tableau', 'excel'], 'cloud...
# 361123  {'analyst_tools': ['sas', 'tableau'], 'program...
# 190795   {'databases': ['db2'], 'programming': ['cobol']}
# 297388  {'analyst_tools': ['power bi'], 'cloud': ['aws...

# %%
df2 = df.copy()

median_salary2 = df2.salary_year_avg.median()

# %%
df2.salary_year_avg = df2.salary_year_avg.fillna(median_salary2)
df2.salary_year_avg
# Out:
# 0         115000.0
# 1         115000.0
# 2         115000.0
# 3         115000.0
# 4         115000.0
#             ...
# 785736    115000.0
# 785737    115000.0
# 785738    115000.0
# 785739    115000.0
# 785740    115000.0
# Name: salary_year_avg, Length: 785741, dtype: float64
